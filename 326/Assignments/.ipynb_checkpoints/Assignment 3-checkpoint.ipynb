# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit

# %% [markdown]
# ### 5b)

# %%
#Formula inside the series for W
def series_W(N,N_final):
    return (1/np.sin(np.pi * N / N_final))

# %%
x_data = np.linspace(2,24,200)
N_final = 25 #Since the series is to go to 25, but that's N
y_data = np.array([series_W(N,N_final) for N in x_data]) #Make an array of the series values for the respective N

# %%
#Applying the entire equation
y_data = y_data/N_final

# %%
plt.plot(x_data,y_data, label = "Work done")
plt.xlabel('$N$', fontsize=14)
plt.ylabel(r'$\left( \frac{16 \pi \epsilon_0 R}{Q^2} \right)W$', fontsize=14)
plt.title("Work required to assemble a ring of charge as a function of increasing point charges")
plt.grid()
plt.legend()
plt.show()

# %%
#Function used in the curve fit
def f(N,a,b,c):
    return a*(np.log(N)**b) + c

# %%
#Applying curve fit
fit_results = curve_fit(f,x_data,y_data)

# %%
#Seeing what is returned
fit_results
# Out:
# (array([-8.15848117e+01,  1.34442719e-04,  8.16647504e+01]),
#  array([[ 3.75491364e+10,  6.18716623e+04, -3.75491368e+10],
#         [ 6.18716623e+04,  1.01949167e-01, -6.18716630e+04],
#         [-3.75491368e+10, -6.18716630e+04,  3.75491373e+10]]))

# %%
#Extracting the approximations for the a, b, and c constants
a_fit = fit_results[0][0]
b_fit = fit_results[0][1]
c_fit = fit_results[0][2]

# %%
a_fit
# Out:
# -81.5848116951828

# %%
b_fit
# Out:
# 0.00013444271947984896

# %%
c_fit
# Out:
# 81.66475040150567

# %%
plt.plot(x_data, y_data, label='Work done')
plt.plot(x_data, f(x_data, a_fit,b_fit,c_fit), label='Best Fit', ls='--')
plt.xlabel('$N$', fontsize=14)
plt.ylabel(r'$\left( \frac{16 \pi \epsilon_0 R}{Q^2} \right)W$', fontsize=14)
plt.title("Work as a function of N")
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ### 5c)

# %%
#Applying the same procedure as above, except for the N range of 100 to 1000 instead
x_data = np.linspace(100,999,100)
N_final = 1000 #Since the series is to go to 25, but that's N-1
y_data = np.array([series_W(N,N_final) for N in x_data]) #Make an array of the series values for the respective N

# %%
plt.plot(x_data,y_data, label = "Work done")
plt.xlabel('$N$', fontsize=14)
plt.ylabel(r'$\left( \frac{16 \pi \epsilon_0 R}{Q^2} \right)W$', fontsize=14)
plt.title("Work required to assemble a ring of charge as a function of increasing point charges")
plt.grid()
plt.legend()
plt.show()

# %%
fit_results = curve_fit(f,x_data,y_data, p0 = [2e-9,0.99,-2.3e-8])

# %%
a_fit = fit_results[0][0]
b_fit = fit_results[0][1]
c_fit = fit_results[0][2]

# %%
a_fit
# Out:
# 9.543957157661907e-09

# %%
b_fit
# Out:
# 2.6188790319338673

# %%
c_fit
# Out:
# 1.808539471913813e-08

# %%
plt.plot(x_data, y_data, label='Work done')
plt.plot(x_data, f(x_data, a_fit,b_fit,c_fit), label='Best Fit', ls='--')
plt.xlabel('$N$', fontsize=14)
plt.ylabel(r'$\left( \frac{16 \pi \epsilon_0 R}{Q^2} \right)W$', fontsize=14)
plt.title("Work as a function of N")
plt.grid()
plt.legend()
plt.show()
